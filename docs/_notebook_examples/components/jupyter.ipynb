# %% [markdown]
# # Jupyter example

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 100)
y = np.cos(2 * np.pi * x / 5)

plt.figure()
plt.plot(x, y)
plt.grid()
plt.show()
